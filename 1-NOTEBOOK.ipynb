# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:
# 1. Numpy
# 2. Pandas
# 3. Scipy

# %%
# %%html
# <table>
#     <tr>
#         <th>Data Science tools</th>
#     </tr>
#     <tr>
#         <td>Jupyter Notebook</td>
#     </tr>
#     <tr>
#         <td>Rstudio</td>
#     <tr>
#         <td>VS Code</td>
#     <tr>
# </table>
# Out:
# <table>
#     <tr>
#         <th>Data Science tools</th>
#     </tr>
#     <tr>
#         <td>Jupyter Notebook</td>
#     </tr>
#     <tr>
#         <td>Rstudio</td>
#     <tr>
#         <td>VS Code</td>
#     <tr>
# </table>

# %% [markdown]
# #### Below are a few examples of evaluating arithmetic expressions in Python
#
# * Addition:
# print(5 + 3)  # Output: 8
#
# * Subtraction:
# print(10 - 4) # Output: 6
#
# * Multiplication:
# print(7 * 2)  # Output: 14
#
# * Division (returns a float):
# print(15 / 3) # Output: 5.0

# %%
# Addition: 
print(5 + 3)  # Output: 8

# Subtraction:
print(10 - 4) # Output: 6

# Multiplication:
print(7 * 2)  # Output: 14

# Division (returns a float):
print(15 / 3) # Output: 5.0
# Out:
# 8
# 6
# 14
# 5.0

# %%
    minutes_input = int(input("Enter time in minutes: ")) # The code to convert minutes to hours

    hours = minutes_input / 60

    print(f"{minutes_input} minutes is equal to {hours:.2f} hours.")
# Out:
# Enter time in minutes:  5
# 5 minutes is equal to 0.08 hours.

# %% [markdown]
#  **Objectives:**
#  * List popular languages for Data Science
#  * Understand key Data Science libraries
#  * Introduce common Data Science tools
#  * Explore basic arithmetic operations in Python
